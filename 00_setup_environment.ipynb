# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.63.0)
# Requirement already satisfied: nest_asyncio in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: gitpython in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (3.1.43)
# Requirement already satisfied: magika in /home/jupyter/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: cloudpickle==3.0.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pydantic==2.7.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (2.7.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.32.3)
# Collecting langchain-google-community
#   Downloading langchain_google_community-1.0.8-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 1.6 MB/s eta 0:00:011
# Collecting google-cloud-discoveryengine
#   Downloading google_cloud_discoveryengine-0.12.1-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: google-api-python-client in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.8.0)
# Collecting langchain-google-cloud-sql-pg
#   Downloading langchain_google_cloud_sql_pg-0.7.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: langchain-google-vertexai in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.0.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.7.4->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.7.4->-r requirements.txt (line 8)) (2.18.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.7.4->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.34.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.12.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (0.16)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (2.32.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (3.25.0)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (2.14.0)
# WARNING: google-cloud-aiplatform 1.63.0 does not provide the extra 'rapid_evaluation'
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython->-r requirements.txt (line 4)) (4.0.11)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in /home/jupyter/.local/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (1.19.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: numpy<2.0,>=1.26 in /opt/conda/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.2 in /home/jupyter/.local/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (4.66.5)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from magika->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: opentelemetry-sdk<2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.26.0)
# Requirement already satisfied: google-cloud-trace<2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.13.5)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: orjson<=3.10.6 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (3.10.6)
# Requirement already satisfied: langchain<0.3,>=0.1.16 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (0.2.14)
# Requirement already satisfied: tenacity<=8.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (8.3.0)
# Requirement already satisfied: langchain-core<0.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (0.2.35)
# Requirement already satisfied: openinference-instrumentation-langchain<0.2,>=0.1.19 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 1)) (0.1.27)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 9)) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->-r requirements.txt (line 9)) (1.26.19)
# Collecting google-api-core<3.0.0,>=2.17.1
#   Downloading google_api_core-2.19.1-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 66.1 MB/s eta 0:00:01
# Collecting langchain-community<0.3.0,>=0.2.1
#   Downloading langchain_community-0.2.12-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 62.4 MB/s eta 0:00:01
# Requirement already satisfied: grpcio<2.0.0,>=1.62.0 in /opt/conda/lib/python3.10/site-packages (from langchain-google-community->-r requirements.txt (line 10)) (1.65.4)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.142.0-py2.py3-none-any.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 37.4 MB/s eta 0:00:01
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client->-r requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client->-r requirements.txt (line 12)) (0.22.0)
# Requirement already satisfied: SQLAlchemy[asyncio]<3.0.0,>=2.0.25 in /opt/conda/lib/python3.10/site-packages (from langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (2.0.31)
# Collecting cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0
#   Downloading cloud_sql_python_connector-1.12.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.9 MB/s  eta 0:00:01
# Collecting pgvector<1.0.0,>=0.2.5
#   Downloading pgvector-0.3.2-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=42.0.0 in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (43.0.0)
# Collecting aiofiles
#   Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (3.10.0)
# Collecting asyncpg>=0.29.0
#   Downloading asyncpg-0.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 70.9 MB/s eta 0:00:01
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from asyncpg>=0.29.0->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=42.0.0->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (1.15.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=42.0.0->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.17.1->langchain-google-community->-r requirements.txt (line 10)) (1.63.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.17.1->langchain-google-community->-r requirements.txt (line 10)) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1)) (4.9)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->-r requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/lib/python3.10/site-packages (from langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.1.104)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (1.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->cloud-sql-python-connector[asyncpg]<2.0.0,>=1.10.0->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (2.3.4)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 10.3 MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.3->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3->google-cloud-aiplatform->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: coloredlogs in /home/jupyter/.local/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->magika->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: sympy in /home/jupyter/.local/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->magika->-r requirements.txt (line 5)) (1.13.2)
# Requirement already satisfied: flatbuffers in /home/jupyter/.local/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->magika->-r requirements.txt (line 5)) (24.3.25)
# Requirement already satisfied: opentelemetry-api in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.26.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: opentelemetry-instrumentation in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.47b0)
# Requirement already satisfied: openinference-semantic-conventions>=0.1.9 in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.1.10)
# Requirement already satisfied: openinference-instrumentation>=0.1.12 in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.1.15)
# Requirement already satisfied: opentelemetry-semantic-conventions in /opt/conda/lib/python3.10/site-packages (from openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.47b0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-gcp-trace<2->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.6.0a0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api->openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api->openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (8.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api->openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (3.19.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy[asyncio]<3.0.0,>=2.0.25->langchain-google-cloud-sql-pg->-r requirements.txt (line 13)) (3.0.3)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain<0.3,>=0.1.16->google-cloud-aiplatform->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jupyter/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->magika->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: setuptools>=16.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-instrumentation->openinference-instrumentation-langchain<0.2,>=0.1.19->google-cloud-aiplatform->-r requirements.txt (line 1)) (61.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jupyter/.local/lib/python3.10/site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->magika->-r requirements.txt (line 5)) (1.3.0)
# Installing collected packages: google-api-core, mypy-extensions, typing-inspect, marshmallow, aiofiles, dataclasses-json, cloud-sql-python-connector, asyncpg, pgvector, langchain-community, google-api-python-client, langchain-google-community, langchain-google-cloud-sql-pg, google-cloud-discoveryengine
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.34.1
#     Uninstalling google-api-core-1.34.1:
#       Successfully uninstalled google-api-core-1.34.1
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'method_async.cpython-310.pyc'
# Consider using the `--user` option or check the permissions.

# %%
# !gcloud services enable aiplatform.googleapis.com sqladmin.googleapis.com servicenetworking.googleapis.com
